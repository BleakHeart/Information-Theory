# %%
import numpy as np
from library import entropy
import matplotlib.pyplot as plt

# %%
p = np.linspace(0, 1, 100)
S = []
for i in p:
    data = np.random.choice([0, 1], p=[i, 1 - i], size=100000)
    S.append(entropy(data))

plt.plot(p, S)
plt.xlabel(r'$p_0$')
plt.ylabel('Entropy (S)')
# Out:
# Text(0, 0.5, 'Entropy (S)')
